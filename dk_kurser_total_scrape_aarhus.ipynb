# %% [markdown]
# <a href="https://colab.research.google.com/github/dawi118/dk_kurser_repo/blob/main/dk_kurser_total_scrape_aarhus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extract text from multiple courses (Aarhus)

# %% [markdown]
# Interactive Python script for extracting course data from the University of Aarhus. Note that this codebase is a proof of concept and requires refinement (scalability, quality of outputs).
#
# Transferability of this web scraping tool to other universities is limited, depending on formatting of destination html.

# %%
# Optional: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# --- Packages ---
# !pip install langdetect
# !pip install bs4
# !pip install chromium
# !pip install playwright # Playwright required to render each web page with javascript in order to extract course information - need to run last

# --- Libraries ---
import re, requests, time, html, unicodedata, json, logging, random, sys, binascii, asyncio, nest_asyncio, os # asyncio allows for playwright to scrape content rendered in js as we go
import pandas as pd
from bs4 import BeautifulSoup, Tag
from urllib.parse import urljoin, urlparse, urldefrag
from langdetect import detect, DetectorFactory
from playwright.async_api import async_playwright, TimeoutError as PWTimeout
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import chromium
import playwright
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect) (1.17.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.12/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from bs4) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (4.15.0)
# Requirement already satisfied: playwright in /usr/local/lib/python3.12/dist-packages (1.55.0)
# Requirement already satisfied: pyee<14,>=13 in /usr/local/lib/python3.12/dist-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pyee<14,>=13->playwright) (4.15.0)
# Requirement already satisfied: chromium in /usr/local/lib/python3.12/dist-packages (0.0.0)

# %% [markdown]
# **1. Scrape Course URLs before retrieving content**

# %%
# ---- Config ----
BASE        = "https://kursuskatalog.au.dk/en"
CAL_YEARS   = [str(y) for y in range(2012, 2028)]      # 2012 to 2027 inclusive, as string
YEAR_CHAIN  = "-".join(CAL_YEARS) # How URL formats course titles and years
START_PAGE  = 1 # Can change for sampling approach
MAX_PAGES   = None              # Optional: None = run until no 'cards' left (page renders course cards using js)
PAUSE       = (0.10, 0.20)      # Delay between scrapes (reduce server load)

OUT_TXT     = Path("au_course_urls.txt")
CHK_SIZE    = 1000              # checkpoint size - set to cache url download into manageable chunks
CHK_PREFIX  = "/content/drive/MyDrive/Thesis/web_scraping/aarhus/aarhus_"         # Optional: for aggregating files across checkpoints once course URLs are identified, if in same file (assumed name convention: arrhus_0_1000, arrhus_1000_2000, ...)
CHK_SUFFIX  = ""                # leave empty

SELECTOR_CARDS        = "li.card"
SELECTOR_CARD_ANCHOR  = "h3.card_title--large a[href], a[href*='/en/course/']"

# --- Helpers ---
# absolutise - converts partial or relative URLs into full ones where necessary
def absolutise(base_url: str, href: str) -> str | None:
    if not href or href.startswith(("mailto:", "tel:", "javascript:")):
        return None
    return urldefrag(urljoin(base_url, href))[0]

# discover_all_urls_async - main function to identify urls from Aarhus and save periodically using playwright
async def discover_all_urls_async():
    all_urls, seen = [], set()
    last_chk_end = 0  # end index of the last chunk file written

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        ctx = await browser.new_context(
            user_agent=("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                        "AppleWebKit/537.36 (KHTML, like Gecko) "
                        "Chrome/124.0.0.0 Safari/537.36"),
            locale="en-GB",
            extra_http_headers={"Accept-Language": "en-GB,en;q=0.9,*;q=0.5"},
            viewport={"width": 1400, "height": 900},
        )
        page = await ctx.new_page()

        pg = START_PAGE
        while True:
            if MAX_PAGES and pg > MAX_PAGES:
                break

            url = f"{BASE}?year={YEAR_CHAIN}&page={pg}"
            try:
                await page.goto(url, wait_until="networkidle", timeout=45000)
            except PWTimeout:
                break

            # Wait for cards to populate
            try:
                await page.wait_for_selector(SELECTOR_CARDS, timeout=6000)
            except PWTimeout:
                pass

            card_l = page.locator(SELECTOR_CARDS)
            card_count = await card_l.count()
            if card_count == 0:
                break

            # Extract one course link per card
            added = 0
            for i in range(card_count):
                card = card_l.nth(i)
                a = card.locator(SELECTOR_CARD_ANCHOR).first
                href = await a.get_attribute("href")
                abs_url = absolutise(url, (href or "").strip())
                if abs_url and "/en/course/" in abs_url and abs_url not in seen:
                    seen.add(abs_url)
                    all_urls.append(abs_url)
                    added += 1

            # Quiet progress line per page
            print(f"Page {pg} complete — added {added} (total {len(all_urls)})")

            # Write any full 1000-link chunks accumulated since last checkpoint
            while last_chk_end + CHK_SIZE <= len(all_urls):
                start = last_chk_end
                end   = last_chk_end + CHK_SIZE
                fname = f"{CHK_PREFIX}{start}_{end}{CHK_SUFFIX}"
                Path(fname).write_text("\n".join(all_urls[start:end]), encoding="utf-8")
                print(f"Saved checkpoint: {fname}")
                last_chk_end = end

            pg += 1
            time.sleep(random.uniform(*PAUSE))

        await browser.close()

    # Produce final consolidated file
    OUT_TXT.write_text("\n".join(all_urls), encoding="utf-8")
    print(f"Saved final list: {OUT_TXT} ({len(all_urls)} URLs)")

    # If the run ended mid-chunk, save the tail to file for re-running
    if last_chk_end < len(all_urls):
        tail_name = f"{CHK_PREFIX}{last_chk_end}_{len(all_urls)}{CHK_SUFFIX}"
        Path(tail_name).write_text("\n".join(all_urls[last_chk_end:]), encoding="utf-8")
        print(f"Saved tail checkpoint: {tail_name}")

    return all_urls

# --- Main ---
nest_asyncio.apply()
urls = await discover_all_urls_async()
asyncio.run(discover_all_urls_async())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-2545831191.py in <cell line: 1>()
#     104 # --- How to run in a notebook ---
#     105 nest_asyncio.apply()
# --> 106 urls = await discover_all_urls_async()
#     107
#     108 # --- How to run as a script ---
#
# /tmp/ipython-input-2545831191.py in discover_all_urls_async()
#      28
#      29     async with async_playwright() as p:
# ---> 30         browser = await p.chromium.launch(headless=True)
#      31         ctx = await browser.new_context(
#      32             user_agent=("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#
# /usr/local/lib/python3.12/dist-packages/playwright/async_api/_generated.py in launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14463
#   14464         return mapping.from_impl(
# > 14465             await self._impl_obj.launch(
#   14466                 executablePath=executable_path,
#   14467                 channel=channel,
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_browser_type.py in launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      96             Browser,
#      97             from_channel(
# ---> 98                 await self._channel.send(
#      99                     "launch", TimeoutSettings.launch_timeout, params
#     100                 )
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_connection.py in send(self, method, timeout_calculator, params, is_internal, title)
#      67         title: str = None,
#      68     ) -> Any:
# ---> 69         return await self._connection.wrap_api_call(
#      70             lambda: self._inner_send(method, timeout_calculator, params, False),
#      71             is_internal,
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_connection.py in wrap_api_call(self, cb, is_internal, title)
#     556             return await cb()
#     557         except Exception as error:
# --> 558             raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559         finally:
#     560             self._api_zone.set(None)
#
# Error: BrowserType.launch: Executable doesn't exist at /root/.cache/ms-playwright/chromium_headless_shell-1187/chrome-linux/headless_shell
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝

# %% [markdown]
# 1.1. Rename and aggregate checkpoint files (optional)

# %%
# --- Config ---
# Define folder_path - replace with appropriate file name
folder_path = "/content/drive/MyDrive/Thesis/web_scraping/aarhus"

# --- Main ----
# List all files in the folder
files = os.listdir(folder_path)

# Iterate through each file and rename it by adding '.csv' extension
for file_name in files:
    # Construct the full path for the original and new file
    old_path = os.path.join(folder_path, file_name)
    new_path = os.path.join(folder_path, file_name + ".csv")

    # Rename the file using the mv shell command
    # !mv "{old_path}" "{new_path}"
    print(f"Renamed '{file_name}' to '{file_name}.csv'")

# List renamed 'csv' files located at folder_path
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Read each CSV file into a DataFrame and store in a list
df_list = []
for f in all_files:
    try:
        # Assuming the CSVs have no header, or you want to treat the first row as data
        df = pd.read_csv(f, header=None)
        # Prune double apostrophes from each cell
        df = df.applymap(lambda x: x.replace('"', '') if isinstance(x, str) else x)
        df_list.append(df)
    except Exception as e:
        print(f"Error reading {f}: {e}")

# Concatenate all DataFrames into a single DataFrame
if df_list:
    combined_df = pd.concat(df_list, ignore_index=True)

    # Define the output file path
    output_file = os.path.join(folder_path, "combined_aarhus_urls.csv")

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv(output_file, index=False, header=False) # Set header=False if no header in original files
    print(f"Successfully combined {len(all_files)} files into {output_file}")
else:
    print("No CSV files found to combine.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-610856187.py in <cell line: 0>()
#       3
#       4 # List all files in the folder
# ----> 5 files = os.listdir(folder_path)
#       6
#       7 # Iterate through each file and rename it by adding '.csv' extension
#
# NameError: name 'os' is not defined

# %% [markdown]
# **2. Execute Scraping against URLs (takes very long time)**

# %%
# --- Packages (assueme not installed earlier) ---
# !pip -q install -U playwright bs4 pandas langdetect nest_asyncio

# Issues using package - try pulling Chromium and any missing OS deps
# !playwright install --with-deps chromium

# --- Libraries ---
import re
import json
import html
import time
import random
import logging
import nest_asyncio, asyncio
nest_asyncio.apply()
from pathlib import Path
from urllib.parse import urljoin

import pandas as pd
from bs4 import BeautifulSoup
from langdetect import detect
from playwright.async_api import async_playwright, TimeoutError as PWTimeout

# --- Config ---
URL_CSV      = "/content/drive/MyDrive/Thesis/web_scraping/aarhus/combined_aarhus_urls.csv" # Switch out!
OUT_JSON     = "aarhus_courses_from_csv.json" # Destination file name
FAILED_TXT   = "aarhus_failed_urls.txt" # Destination (failed extractions)
CHECKPOINT_EVERY = 100     # write partial file every x courses (adjust based on speed)
CONCURRENCY = 3       # number of pages viewable simultaneously (with playwright)

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en,en-GB;q=0.9,*;q=0.5",
} # configuring a 'human-like' agent for web scraping

# Logging output settings
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)
log = logging.getLogger("au")

# --- Helpers ---
# norm_text - normalise html text for extraction
def norm_text(s: str | None) -> str | None:
    if not s: return None
    t = html.unescape(s).replace("\xa0", " ")
    t = re.sub(r"\s+", " ", t).strip()
    return t or None

# load_course_urls - extract course_urls downloaded earlier from csv_path
def load_course_urls(csv_path: str) -> list[str]:
    df = pd.read_csv(csv_path, dtype=str, keep_default_na=False)
    urls = []
    for col in df.columns:
        for val in df[col].astype(str):
            s = (val or "").strip()
            if s.startswith("http") and "kursuskatalog.au.dk" in s and "/course/" in s:
                urls.append(s)
    # de-duplicate (preserving order)
    seen, out = set(), []
    for u in urls:
        if u not in seen:
            seen.add(u); out.append(u)
    return out

# section_text_after - extracts relevant blocks of content following specific headings
def section_text_after(bs_heading) -> str:
    parts = []
    for sib in bs_heading.next_siblings:
        name = getattr(sib, "name", None)
        if name in ("h1","h2","h3","h4","h5","h6"):
            break
        if hasattr(sib, "get_text"):
            t = sib.get_text(" ", strip=True)
        else:
            t = str(sib).strip() if isinstance(sib, str) else ""
        if t:
            parts.append(t)
    return norm_text(" ".join(parts)) or ""

# extract_title - extracts course title from page 'h1'
def extract_title(soup: BeautifulSoup) -> str | None:
    root = soup.find("main", id="content") or soup
    h1 = (root.select_one("div.page__content__block h1.list-navigator__header")
          or root.find("h1"))
    if not h1:
        return None
    raw = norm_text(h1.get_text(" ", strip=True))
    if not raw:
        return None
    # remove leading code like "5647: Title"
    m = re.match(r"^\s*[A-Za-z0-9._-]+\s*:\s*(.+)$", raw)
    return m.group(1) if m else raw

# extract_placement - extracts placement variable from page
def extract_placement(soup: BeautifulSoup) -> str | None:
    root = soup.find("main", id="content") or soup
    h2 = root.select_one("div.page__content__block h2.list-navigator__subtitle")
    return norm_text(h2.get_text(" ", strip=True)) if h2 else None

# extract_placement - extracts 'stads uva code' variable from page
def extract_stads_code(soup: BeautifulSoup) -> str | None:
    sp = soup.find("span", class_="copy-to-clipboard__this")
    code = norm_text(sp.get_text(strip=True)) if sp else None
    return code if code and re.search(r"[A-Za-z0-9]", code) else None

# extract_fact_list - extracts credit, level and language variables from normalised fact list on webpage
def extract_fact_list(soup: BeautifulSoup) -> dict:
    out = {}
    for lab in soup.select(".fact-list__item__label"):
        label = norm_text(lab.get_text(" ", strip=True) or "")
        valnode = lab.find_next_sibling(class_="fact-list__item__value") or lab.parent.find(class_="fact-list__item__value")
        value = norm_text(valnode.get_text(" ", strip=True) if valnode else "")
        if not label or not value:
            continue
        lbl = label.lower()
        if "ects" in lbl:
            out["credit"] = value
        elif "level" in lbl:
            out["level"] = value
        elif "language" in lbl:
            out["language"] = value
    return out

# extract_department - extracts department variable from beautiful soup text
def extract_department(soup: BeautifulSoup) -> str | None:
    for dt in soup.find_all("dt"):
        label = norm_text(dt.get_text(" ", strip=True) or "")
        if label and label.lower().strip() == "department":
            dd = dt.find_next_sibling("dd")
            if dd:
                return norm_text(dd.get_text(" ", strip=True))
    return None

# extract_content_and_lo - extract content and learning outcome text from course description
def extract_content_and_lo(soup: BeautifulSoup) -> tuple[str | None, str | None]:
    cols = soup.select("div.course-details__column")
    content, outcomes = None, None

    for col in cols:
        for h in col.find_all(["h2","h3"]):
            t = norm_text(h.get_text(" ", strip=True) or "")
            if not t: continue
            tl = t.lower()
            if (("course content" in tl or tl == "content") and not content):
                content = section_text_after(h)
            elif (("description of qualifications" in tl) or ("learning outcomes" in tl)) and not outcomes:
                outcomes = section_text_after(h)
    if not content and cols:
        content = norm_text(" ".join([norm_text(c.get_text(" ", strip=True) or "") or "" for c in cols]))
    return content, outcomes

# extract_coordinators_and_profile_links - attempt to click through coordinator text to extract course coordinator details (i.e. name and email)
def extract_coordinators_and_profile_links(soup: BeautifulSoup) -> tuple[list[str], list[str]]:
    names = []
    profile_links = []

    dd = None
    for dt in soup.find_all("dt"):
        label = norm_text(dt.get_text(" ", strip=True) or "")
        if label and label.lower().startswith("course coordinator"):
            dd = dt.find_next_sibling("dd")
            break
    root = dd or soup

    for div in root.select(".profile-image__label__title"):
        n = norm_text(div.get_text(" ", strip=True))
        if n: names.append(n)
    for img in root.select("img.profile-image[alt]"):
        n = norm_text(img.get("alt"))
        if n: names.append(n)
    for tr in root.select(".truncator__content"):
        t = norm_text(tr.get_text(" ", strip=True))
        if t: names.append(t)

    for a in root.find_all("a", href=True):
        href = a["href"].strip()
        if href.startswith("mailto:"):
            continue
        if "au.dk" in href:
            profile_links.append(urljoin("https://kursuskatalog.au.dk", href))

    # de-duplicate names
    names = list(dict.fromkeys(names))
    profile_links = list(dict.fromkeys(profile_links))
    return names, profile_links

# ---  Main ---
# render_and_parse (async) - attempt to render webpage using Playwright to obtain details
async def render_and_parse(context, url: str) -> BeautifulSoup | None:
    page = await context.new_page()
    try:
        await page.route("**/*", lambda route: (
            route.continue_() if route.request.resource_type in {"document","script","xhr","fetch","stylesheet"} else route.abort()
        ))
    except Exception:
        pass

    try:
        await page.goto(url, wait_until="domcontentloaded", timeout=30000)
        # Wait for either the title or the content root; keep going if timeout
        try:
            await page.wait_for_selector("h1.list-navigator__header, main#content", timeout=10000)
        except PWTimeout:
            pass
        html_str = await page.content()
        return BeautifulSoup(html_str, "html.parser")
    except Exception as e:
        log.warning("Nav failed: %s (%s)", url, e)
        return None
    finally:
        await page.close()

# fetch_profile_emails (async) - attempt to use profile_url to extract coordinator details on a separate page
async def fetch_profile_emails(context, profile_url: str) -> list[str]:
    page = await context.new_page()
    emails = []
    try:
        await page.goto(profile_url, wait_until="domcontentloaded", timeout=25000)
        # try both immediately and after a short wait (some profiles populate slightly later)
        sel = "span.contact-list__item__content__full-label"
        try:
            await page.wait_for_selector(sel, timeout=6000)
        except PWTimeout:
            pass
        nodes = await page.locator(sel).all_inner_texts()
        for t in nodes:
            t = norm_text(t)
            if t and "@" in t:
                emails.append(t)
    except Exception:
        pass
    finally:
        await page.close()
    return list(dict.fromkeys(emails))


# scrape_one - attempt to scrape required information from a single course page
async def scrape_one(context, url: str) -> dict | None:
    soup = await render_and_parse(context, url)
    if not soup:
        return None

    data = {
        "source_url": url,
        "year": None,
        "course_code": None,
        "course_title": None,
        "credit": None,
        "placement": None,
        "contracting_department": None,
        "coordinators": None,
        "coordinator_emails": None,
        "content": None,
        "learning_outcomes": None,
        "knowledge": None,
        "skills": None,
        "competencies": None,
        "language": None,
        "level": None,
        "web_lang": None
    }

    # Title & Placement
    data["course_title"] = extract_title(soup)
    data["placement"]    = extract_placement(soup)
    if data["placement"]:
        m = re.search(r"(\d{4})", data["placement"])
        if m: data["year"] = m.group(1)

    # STADS code
    data["course_code"] = extract_stads_code(soup)

    # Facts
    facts = extract_fact_list(soup)
    for k, v in facts.items():
        data[k] = v

    # Department
    data["contracting_department"] = extract_department(soup)

    # Content & Learning outcomes
    content, outcomes = extract_content_and_lo(soup)
    data["content"]           = content
    data["learning_outcomes"] = outcomes

    # Coordinators + emails
    names, profiles = extract_coordinators_and_profile_links(soup)
    data["coordinators"] = names or None

    emails = []
    for prof in profiles[:3]:
        emails.extend(await fetch_profile_emails(context, prof))
    data["coordinator_emails"] = list(dict.fromkeys(emails)) or None

    # Language detection fallback
    sample = data["content"] or data["learning_outcomes"] or data["course_title"] or ""
    try:
        data["web_lang"] = detect(sample) if sample else "unknown"
    except Exception:
        data["web_lang"] = "unknown"

    return data

# main - script to run all functions (initiate below)
async def main():
    # Load URLs from step 1
    urls = load_course_urls(URL_CSV)
    print(f"Loaded {len(urls)} course URLs from CSV")

    records, failed = [], []

    # Define concurrency (default = 3)
    sem = asyncio.Semaphore(CONCURRENCY)

    # Launch playwright through chromium browser and commence scraping
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent=HEADERS["User-Agent"], locale="en-GB")

        # Cycle through pages and append records
        async def runner(u: str, idx: int):
            async with sem:
                rec = await scrape_one(context, u)
                if rec: records.append(rec)
                else:   failed.append(u)

                # sample print every 50 (For testing!)
                if idx % 10 == 0:
                    print(f"\n=== SAMPLE @ {idx}/{len(urls)} ===")
                    print(json.dumps(records[-1] if records else {"note":"no records yet"}, ensure_ascii=False, indent=2))
                    print("---------------------")

                # checkpoint
                if idx % CHECKPOINT_EVERY == 100: # every 100 scrapes, create checkpoint and save as JSON
                    ck = f"aarhus_courses_ck_{idx-CHECKPOINT_EVERY+1}_{idx}.json"
                    Path(ck).write_text(json.dumps(records, ensure_ascii=False, indent=2), encoding="utf-8")
                    log.info("Checkpoint saved: %s (records so far: %d)", ck, len(records))

                # Delay between tasks - randomise when scraping
                await asyncio.sleep(random.uniform(0.05, 0.12))

        # Run an event look using tasks (with concurrency to allow for multiple scrapes at the same time)
        tasks = []
        for i, u in enumerate(urls, start=1):
            tasks.append(asyncio.create_task(runner(u, i)))

            # limit queue of tasks to avoid huge task list in memory
            if len(tasks) >= 2000:
                await asyncio.gather(*tasks)
                tasks = []
        if tasks:
            await asyncio.gather(*tasks)

        # close browser after success
        await context.close()
        await browser.close()

    # write outputs to OUT_JSON
    Path(OUT_JSON).write_text(json.dumps(records, ensure_ascii=False, indent=2), encoding="utf-8")
    print(f"\nSaved {len(records)} records → {OUT_JSON}")

    if failed:
        Path(FAILED_TXT).write_text("\n".join(failed), encoding="utf-8")
        print(f"Saved {len(failed)} failed URLs → {FAILED_TXT}")

# --- Run ---
if __name__ == "__main__":
    import asyncio, sys
    try:
        # If there's already a running loop, run main() inside this
        asyncio.get_running_loop()
        nest_asyncio.apply()
        asyncio.get_event_loop().run_until_complete(main())

    except RuntimeError:
        # No running loop (i.e. normal Python script on first run) - safe to use asyncio.run()
        asyncio.run(main())
# Out:
# Loaded 61705 course URLs from CSV
#
# === SAMPLE @ 10/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/58688/10-ECTS-Life-histories-and-biographical-research",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 20/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/65434/10-ECTS-Quantitative-Research-Methods",
#   "year": "2016",
#   "course_code": "171162U003",
#   "course_title": "(10 ECTS) Quantitative Research Methods",
#   "credit": "10",
#   "placement": "Autumn semester 2016",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "Not specified",
#     "ECTS 10 Level Master Language of instruction Danish Type of course Ordinary Primary programme Master's Degree Programme in Educational Sociology Related programmes Master's Degree Programme in Educational Theory and Curriculum Studies (Mathematics), Master's Degree Programme in Educational Psychology, Master's Degree Programme in Educational Theory and Curriculum Studies (Material Culture), Master's Degree Programme in Educational Theory and Curriculum Studies (Music Education), Master's Degree Programme in Educational Theory and Curriculum Studies (Danish), Master's Degree Programme in General Education, Master's Degree Programme in Philosophy of Education Department Danish School of Education Faculty Arts Location Copenhagen STADS UVA code 171162U003 Copy UVA code"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more",
#   "learning_outcomes": "Read more Not specified",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "en"
# }
# ---------------------
#
# === SAMPLE @ 30/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/58573/20-ECTS-Historical-perspectives-on-Education",
#   "year": "2015",
#   "course_code": "171152U005",
#   "course_title": "(20 ECTS) Historical perspectives on Education",
#   "credit": "20",
#   "placement": "Autumn semester 2015",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "Valgfaget retter sig mod kandidatstuderende på IUP (særligt pædagogisk sociologi og uddannelsesvidenskab). Faget vil beskæftige sig med teoretiske og metodiske forudsætninger for at anlægge historiske perspektiver og foretage historiske analyser af problemstillinger indenfor pædagogik og uddannelsesfeltet bredt set. Faget ruster de studerende til at arbejde historisk ved at de ”går i arkivet” og udfører empirisk baserede, teoretisk reflekterede analyser af eget materiale (f.eks. institutionsarkiver, policydokumenter, tidsskrifter, livshistoriske interviews, erindringer, mv.). Modulet bygges op som en kombination af forelæsninger og seminarer. I forelæsningerne lægges vægt på at introducere forskellige historiske skoler og traditioner, centrale begreber og teorier, samt kildetyper og metodiske greb. Forelæsningerne vil tage afsæt i konkrete historiske analyser indenfor feltet pædagogik og uddannelse og gå i dybden med kendte teoretikere så som Foucault, Bourdieu og Elias og giver eksempler på. Seminarierne er orienterede mod at diskutere og vejlede de studerendes selvstændige arbejde med eget empiriske materiale.",
#     "Not specified",
#     "Bemærk at valgfaget kun udbydes i København",
#     "ECTS 20 Level Master Language of instruction Danish Type of course Ordinary Primary programme Master's Degree Programme in Educational Sociology Related programmes Master's Degree Programme in Educational Theory and Curriculum Studies (Mathematics), Master's Degree Programme in Educational Theory and Curriculum Studies (Material Culture), Master's Degree Programme in Educational Theory and Curriculum Studies (Music Education), Master's Degree Programme in General Education, Master's Degree Programme in Education Science Department Danish School of Education Faculty Arts Location Copenhagen STADS UVA code 171152U005 Copy UVA code"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more Valgfaget retter sig mod kandidatstuderende på IUP (særligt pædagogisk sociologi og uddannelsesvidenskab). Faget vil beskæftige sig med teoretiske og metodiske forudsætninger for at anlægge historiske perspektiver og foretage historiske analyser af problemstillinger indenfor pædagogik og uddannelsesfeltet bredt set. Faget ruster de studerende til at arbejde historisk ved at de ”går i arkivet” og udfører empirisk baserede, teoretisk reflekterede analyser af eget materiale (f.eks. institutionsarkiver, policydokumenter, tidsskrifter, livshistoriske interviews, erindringer, mv.). Modulet bygges op som en kombination af forelæsninger og seminarer. I forelæsningerne lægges vægt på at introducere forskellige historiske skoler og traditioner, centrale begreber og teorier, samt kildetyper og metodiske greb. Forelæsningerne vil tage afsæt i konkrete historiske analyser indenfor feltet pædagogik og uddannelse og gå i dybden med kendte teoretikere så som Foucault, Bourdieu og Elias og giver eksempler på. Seminarierne er orienterede mod at diskutere og vejlede de studerendes selvstændige arbejde med eget empiriske materiale.",
#   "learning_outcomes": "Read more Not specified",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "da"
# }
# ---------------------
#
# === SAMPLE @ 40/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/64882/20-ECTS-Public-Organizations-Leadership-and-Governance",
#   "year": "2016",
#   "course_code": "171152U020",
#   "course_title": "(20 ECTS) Public Organizations, Leadership and Governance",
#   "credit": "20",
#   "placement": "Autumn semester 2016",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "Not specified",
#     "ECTS 20 Level Master Language of instruction Danish Type of course Ordinary Primary programme Master's Degree Programme in Educational Sociology Related programmes Master's Degree Programme in Educational Theory and Curriculum Studies (Mathematics), Master's Degree Programme in General Education Department Danish School of Education Faculty Arts Location Aarhus STADS UVA code 171152U020 Copy UVA code"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more",
#   "learning_outcomes": "Read more Not specified",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "en"
# }
# ---------------------
#
# === SAMPLE @ 50/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/133785/P-Empirical-Asset-Pricing",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 60/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/12720/-",
#   "year": "2012",
#   "course_code": "163112U007",
#   "course_title": "-",
#   "credit": "5",
#   "placement": "Spring semester 2012",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "Hver problemstilling tilrettelægges med udgangspunkt i, at der individuelt eller gruppevis skal udarbejdes en skriftlig rapport på dansk eller engelsk, som dokumenterer den opnåede indsigt og overblik og dømmekraft. En projektgruppe kan bestå af højst fem studerende. Hver projektgruppe tildeles en vejleder.",
#     "Efter gennemført modul kan den studerende på et videnskabeligt grundlag, forstået som et kritisk, systematisk og teoretisk funderet grundlag: \" Demonstrere overblik og dømmekraft vedrørende en udvalgt forskningsmetodes muligheder og begrænsninger i forhold til det pædagogiske problemfelt. Projektarbejdet skal tage udgangspunkt i en pædagogisk og/eller didaktisk problemstilling, som eksplicit relaterer sig til det ovenfor angivne mål med projektarbejdet. Inden for denne ramme afgrænses og formuleres problemstillingen af de(n) studerende selv, dog således at projektarbejdet kan gennemføres med en arbejdsindsats svarende til 5 ECTSpoint (1/12 årsværk).",
#     "ECTS 5 Level Master Language of instruction Danish Type of course Ordinary Primary programme Master's Degree Programme in Educational Theory and Curriculum Studies (Material Culture) Department Danish School of Education Faculty Arts Location Copenhagen STADS UVA code 163112U007 Copy UVA code"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more Hver problemstilling tilrettelægges med udgangspunkt i, at der individuelt eller gruppevis skal udarbejdes en skriftlig rapport på dansk eller engelsk, som dokumenterer den opnåede indsigt og overblik og dømmekraft. En projektgruppe kan bestå af højst fem studerende. Hver projektgruppe tildeles en vejleder.",
#   "learning_outcomes": "Read more Efter gennemført modul kan den studerende på et videnskabeligt grundlag, forstået som et kritisk, systematisk og teoretisk funderet grundlag: \" Demonstrere overblik og dømmekraft vedrørende en udvalgt forskningsmetodes muligheder og begrænsninger i forhold til det pædagogiske problemfelt. Projektarbejdet skal tage udgangspunkt i en pædagogisk og/eller didaktisk problemstilling, som eksplicit relaterer sig til det ovenfor angivne mål med projektarbejdet. Inden for denne ramme afgrænses og formuleres problemstillingen af de(n) studerende selv, dog således at projektarbejdet kan gennemføres med en arbejdsindsats svarende til 5 ECTSpoint (1/12 årsværk).",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "da"
# }
# ---------------------
#
# === SAMPLE @ 70/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/31173/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 80/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/44271/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 90/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/56812/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 100/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/54784/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 110/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/58440/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 120/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/73634/-",
#   "year": "2017",
#   "course_code": "172142U007",
#   "course_title": "-",
#   "credit": "10",
#   "placement": "Autumn semester 2017",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "-",
#     "Formålet med modulet er at sætte de studerende i stand til at udvikle organisatoriske uddannelsesforløb baseret på en kritisk og reflekteret analyse af behov og muligheder for udvikling samt en reflekteret tilgang til begrebsliggørelsen af uddannelsesbegrebet i organisatoriske sammenhænge. Modulet indeholder viden om organisationsudvikling, forandringsprocesser, organisatorisk læring, praksislæring, curriculum-planlægning og didaktisk teori, samt forskellige tilgange til evaluering af sådanne udviklingsforløb, og giver de studerende mulighed for at anvende disse i konstruktive og kritiske samspil med relevante organisatoriske praksisser. Modulet introducerer til teorier på to overordnede teoretiske forskningsfelter: organisationsudvikling samt organisatorisk læring. De studerende skaber i starten af modulet kontakt til en virksomhed, med det formål i samspil med virksomheden at udvikle et uddannelsesforløb og senere evaluere dette. De studerende skal anvende deres metodiske kundskaber fra første semester til at designe et udviklingsforløb som en art aktionsforskningsforløb, dvs. et forløb, hvor de studerende løbende problem- og målformulerer i forhold til og i samspil med en empirisk udviklingspraksis. De studerende skal løbende dokumentere, beskrive og reflektere over udviklingsforløbet ud fra de teoretiske universer, der introduceres i forløbet.",
#     "Den studerende har efter gennemførelse af modulet følgende viden, færdigheder og kompetencer: Viden om og på et reflekteret og kritisk grundlag at kunne beskrive og redegøre for viden og teorier om organisationsudvikling, organisatorisk læring, forskellige læringsforståelser og uddannelsesforløb. Færdigheder i at foretage kritisk og reflekteret analyse af behov og muligheder for udvikling. Kompetencer til at udvikle og evaluere organisatoriske uddannelsesforløb på et teoretisk velfunderet grundlag.",
#     "ECTS 10 Level Master Language of instruction Danish Hours - week - period Ugedag og tidspunkt vil kunne ses på følgende hjemmeside snarest muligt: http://autumnschedule.au.dk/dk/ Type of course Ordinary Primary programme Master's Degree Programme in Education Science Related programmes Master's Degree Programme in Educational Theory and Curriculum Studies (Mathematics), Master's Degree Programme in Educational Psychology, Master's Degree Programme in Educational Theory and Curriculum Studies (Material Culture), Master's Degree Programme in Educational Theory and Curriculum Studies (Music Education), Master's Degree Programme in Educational Theory and Curriculum Studies (Danish), Master's Degree Programme in General Education, Master's Degree Programme in Philosophy of Education Department Danish School of Education Faculty Arts Location Aarhus STADS UVA code 172142U007 Copy UVA code",
#     "- -"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more Formålet med modulet er at sætte de studerende i stand til at udvikle organisatoriske uddannelsesforløb baseret på en kritisk og reflekteret analyse af behov og muligheder for udvikling samt en reflekteret tilgang til begrebsliggørelsen af uddannelsesbegrebet i organisatoriske sammenhænge. Modulet indeholder viden om organisationsudvikling, forandringsprocesser, organisatorisk læring, praksislæring, curriculum-planlægning og didaktisk teori, samt forskellige tilgange til evaluering af sådanne udviklingsforløb, og giver de studerende mulighed for at anvende disse i konstruktive og kritiske samspil med relevante organisatoriske praksisser. Modulet introducerer til teorier på to overordnede teoretiske forskningsfelter: organisationsudvikling samt organisatorisk læring. De studerende skaber i starten af modulet kontakt til en virksomhed, med det formål i samspil med virksomheden at udvikle et uddannelsesforløb og senere evaluere dette. De studerende skal anvende deres metodiske kundskaber fra første semester til at designe et udviklingsforløb som en art aktionsforskningsforløb, dvs. et forløb, hvor de studerende løbende problem- og målformulerer i forhold til og i samspil med en empirisk udviklingspraksis. De studerende skal løbende dokumentere, beskrive og reflektere over udviklingsforløbet ud fra de teoretiske universer, der introduceres i forløbet.",
#   "learning_outcomes": "Read more Den studerende har efter gennemførelse af modulet følgende viden, færdigheder og kompetencer: Viden om og på et reflekteret og kritisk grundlag at kunne beskrive og redegøre for viden og teorier om organisationsudvikling, organisatorisk læring, forskellige læringsforståelser og uddannelsesforløb. Færdigheder i at foretage kritisk og reflekteret analyse af behov og muligheder for udvikling. Kompetencer til at udvikle og evaluere organisatoriske uddannelsesforløb på et teoretisk velfunderet grundlag.",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "da"
# }
# ---------------------
#
# === SAMPLE @ 130/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/61944/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 140/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/62001/-",
#   "year": "2017",
#   "course_code": "172141U012",
#   "course_title": "-",
#   "credit": "10",
#   "placement": "Spring semester 2017",
#   "contracting_department": "Danish School of Education",
#   "coordinators": [
#     "Kirsten Hyldgaard",
#     "Klassiske og aktuelle videnskabsteoretiske positioner, der er relevante for uddannelsesforskning/pædagogisk forskning og tænkning vedrørende videnskabens subjekt og objekt, sandhed og viden. Klassiske og aktuelle teorier af betydning for den pædagogiske tænkning vedrørende den mulige formelle skelnen mellem videnskab og ikke-videnskab, herunder forholdet mellem filosofi og videnskab. Forskellige konfliktuerende positioner belyses, såsom fænomenologisk og hermeneutisk versus et strukturalistisk og diskursteoretisk perspektiv, kritisk rationalisme versus paradigmetænkning, den historiefilosofiske udviklingstanke versus den genealogiske herkomsttanke, kognitionspsykologiske versus psykoanalytiske, psykodynamiske perspektiver. Forskellige former for konstruktivisme versus essentialisme og realisme introduceres. Positionerne belyses gennem aktuel forskning, og der er fokus på, hvordan videnskabsteori informerer diskussionen af kvalitet i forskningen.",
#     "Målet er, at de studerende: Opnår kendskab til klassiske og nutidige videnskabsteoretiske positioner vedrørende spørgsmålet om forskellige former for videnskabelighed, herunder forholdet mellem videnskab og andre former for tænkning. Opnår kendskab til forskellige vidensidealer og gyldighedskriterier i såvel formelt som historisk perspektiv, herunder forholdet mellem viden og sandhed, anvendelighed og operationaliserbarhed. Opnår kendskab til forskelle mellem at analysere, beskrive, forklare og forstå. Kan identificere og analysere kriterier for gyldig viden og videnskabelige teoriers filosofiske grundantagelser vedrørende det videnskabelige subjekt og objekt. Kan anvende videnskabsteori til kritisk at analysere og vurdere aktuel pædagogisk forsknings videnskabelige status. Kan reflektere over og begrunde teoretiske og metodiske valg.",
#     "ECTS 10 Level Bachelor Language of instruction Danish Hours - week - period Lokaler se timeplanere: http://springschedule.au.dk/dk/default.aspx Forbehold for ændringer tages. Type of course Ordinary Primary programme Bachelor's Degree Programme in Education Science Department Danish School of Education Faculty Arts Location Copenhagen STADS UVA code 172141U012 Copy UVA code",
#     "K Kirsten Hyldgaard",
#     "Undervisningsform Undervisningen tilrettelægges som en vekslen mellem forelæsninger om udvalgte temaer, studieaktiviteter relateret til mindre opgaver, præsentation og vejledning af projekter. Der er knyttet holdundervisning til modulet. Undervisningssprog Dansk - der kan forekomme enkelte undervisningsgange på engelsk.",
#     "400-800 sider."
#   ],
#   "coordinator_emails": null,
#   "content": "Read more Klassiske og aktuelle videnskabsteoretiske positioner, der er relevante for uddannelsesforskning/pædagogisk forskning og tænkning vedrørende videnskabens subjekt og objekt, sandhed og viden. Klassiske og aktuelle teorier af betydning for den pædagogiske tænkning vedrørende den mulige formelle skelnen mellem videnskab og ikke-videnskab, herunder forholdet mellem filosofi og videnskab. Forskellige konfliktuerende positioner belyses, såsom fænomenologisk og hermeneutisk versus et strukturalistisk og diskursteoretisk perspektiv, kritisk rationalisme versus paradigmetænkning, den historiefilosofiske udviklingstanke versus den genealogiske herkomsttanke, kognitionspsykologiske versus psykoanalytiske, psykodynamiske perspektiver. Forskellige former for konstruktivisme versus essentialisme og realisme introduceres. Positionerne belyses gennem aktuel forskning, og der er fokus på, hvordan videnskabsteori informerer diskussionen af kvalitet i forskningen.",
#   "learning_outcomes": "Read more Målet er, at de studerende: Opnår kendskab til klassiske og nutidige videnskabsteoretiske positioner vedrørende spørgsmålet om forskellige former for videnskabelighed, herunder forholdet mellem videnskab og andre former for tænkning. Opnår kendskab til forskellige vidensidealer og gyldighedskriterier i såvel formelt som historisk perspektiv, herunder forholdet mellem viden og sandhed, anvendelighed og operationaliserbarhed. Opnår kendskab til forskelle mellem at analysere, beskrive, forklare og forstå. Kan identificere og analysere kriterier for gyldig viden og videnskabelige teoriers filosofiske grundantagelser vedrørende det videnskabelige subjekt og objekt. Kan anvende videnskabsteori til kritisk at analysere og vurdere aktuel pædagogisk forsknings videnskabelige status. Kan reflektere over og begrunde teoretiske og metodiske valg.",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Bachelor",
#   "web_lang": "da"
# }
# ---------------------
#
# === SAMPLE @ 150/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/65326/-",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 160/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/85086/101E18-Advanced-political-theory-normative-analysis-of-public-policy",
#   "year": "2018",
#   "course_code": "431182U023",
#   "course_title": "101E18 Advanced political theory: normative analysis of public policy",
#   "credit": "20",
#   "placement": "Autumn semester 2018",
#   "contracting_department": "Department of Political Science",
#   "coordinators": [
#     "Søren Flinch Midtgaard, midtgaard@ps.au.dk"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more The core course focuses on central normative theories and applying them to important social and global issues. We will concentrate on the following four policy areas: Immigration: To which extent should well-off, liberal states accept refugees and immigrants and which rights should we extend to them? Climate: How should we distribute the costs of climate change? War: Under which circumstances is it just to start a war and what characterises just warfare? Education: How should the education system balance the interests of children, parents and the state regarding what should be learnt and how? Within each area, we will discuss what the relevant normative considerations are and whether concrete political decisions can be justified. Among many other things, we will discuss the EU refugee agreement with Turkey, the intervention in Libya, how the interests of future generations are attended to in the global climate agreements and whether (religious) charter schools are problematic for the welfare state. The course aims to strengthen the participants’ normative theoretical knowledge regarding these policy areas and generally train their ability to balance different normative considerations. The core course builds on the department’s bachelor course in political theory. The latter introduces central isms and concepts within political theory. The core course will also present the debated issue of political theory methods and exemplify this debate using concrete cases. The goal is that participants become able to carry out, critically and creatively, normative analyses of societal problems and concrete political decisions, evaluate the strengths of arguments presented in the public debate and develop their own positions. Skills that can be crucial in future jobs where analysis, advice to decision-makers and leadership are important. ”Normative concepts such as freedom, democracy and justice are of great importance to political communication and to the content of many political decisions and their implementation. Regardless of whether as a future civil servant, one is to advise politicians or whether one’s job is to research political/administrative matters, one needs to understand the different meanings of concepts and how to apply them to concrete policy areas.” ( Thomas Gregersen, Senior Advisor, The Prime Minister’s Office ) The teaching format of the course is designed to train the participants’ oral and written skills. Within each of the course’s four policy areas, the participants will work in small groups to develop a (short) synopsis regarding a self-chosen research question. Each policy area covered consists of a module of five lessons that ends with the different groups presenting their synopses to each other. The whole course ends with a discussion of the participants’ exam synopses and a presentation and discussion of how to do a master thesis within political theory.",
#   "learning_outcomes": "Read more The seminar provides advanced and in-depth treatment of an area of political science research based on an account and discussion of various positions as well as discussions and possibly data sources and methods derived from conventional and contemporary research literature. These research areas may fall within the following fields: Comparative politics, political behaviour and attitude formation, public administration, political institutions and public policy, international politics, political theory and political sociology. The goal of the core course in political science is to strengthen the student’s ability to systematically understand, analyse, discuss and independently assess a large amount of research literature and adopt a critical approach to the course literature. Objectives for the core course in political science: The student is able to account for selected theories, methods and issues within the research area in question at the highest academic level. The student is able to identify the most recent Danish and international research results and any needs for further research within the research area in question. In continuation thereof, the student is able to independently formulate an academic hypothesis related to the course theories, methods and issues and to key and current discussions within the research area in question. The student is able to compare the theories, methods and issues presented throughout the course and identify their differences/similarities and strengths/weaknesses. The student is able to apply theories, approaches, methods and data that are relevant for the analysis of the selected issues. The student is able to assess the fruitfulness of the course theories, methods and their scope of application. The student is able to confidently communicate an academic issue and structure an oral academic presentation and engage in a scholarly dialogue about the topic at hand. The specific objectives for this module are: The course aims to make the student able to: Account for selected normative theories, methods and concepts in the study of national and international institutions and structures. Compare selected normative theories, methods and concepts and identify their differences/similarities and strengths/weaknesses. Apply selected normative theories, methods and concepts to the analysis of societal problems and concrete political decisions. Including identifying the differences/similarities and strengths/weaknesses of different theories, methods and concepts. Evaluate the relevance and usefulness of applying the course’s theories, methods and concepts to analyse certain societal problems and concrete political decisions. Independently formulate a relevant research questions and apply normative theories, methods and concepts to analyse it.",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "en"
# }
# ---------------------
#
# === SAMPLE @ 170/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/89759/101F19-Advanced-Public-Administration",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 180/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/93999/102E19-Public-Policy-and-Finance",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 190/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/70409/102N-Advanced-Public-Administration",
#   "year": "2017",
#   "course_code": "431162U091",
#   "course_title": "102N Advanced Public Administration",
#   "credit": "20",
#   "placement": "Spring semester 2017",
#   "contracting_department": "Department of Political Science",
#   "coordinators": [
#     "Christian Bøtcher Jacobsen",
#     "Heidi Houlberg Salomonsen",
#     "Søren Serritzlew",
#     "This seminar provides the participants with in-depth knowledge of the public sector which may be relevant for future jobs and further studies within public administration. We will focus on three main themes: a) coordination and management in the public sector; b) public employees; c) The relationship between the administration and political stakeholders – primarily the citizens. More specifically, we focus on discussing questions such as: Why is coordination and management so difficult in the public sector? What is the relationship between the political leadership and the administration? How can we measure performance in public institutions, and what can we use the knowledge for? How can we manage highly professionalized civil servants and public service providers – and is it even possible? Is there an association between citizen satisfaction and public sector performance? And how can the citizens be motivated to engage in public service co-production initiatives? Discussion of these questions is based on a curriculum focusing on more recent Danish and international scholarly contributions of theoretical as well as empirical content. A main aim of the course is to strengthen the participants written as well as oral performance skills. The oral skills are trained through discussions and group-based casework in class as well as between classes and in the final oral exam. The writing skills are practiced through the requirement of handing in small written assignments during the course where participants should demonstrate ability to develop and describe research designs tackling current empirical challenges in public administration. Hence, the course also serves as preparation for participants’ final thesis writing.",
#     "The seminar provides advanced and in-depth treatment of an area of political science research based on an account and discussion of various positions as well as discussions and possibly data sources and methods derived from conventional and contemporary research literature. These research areas may fall within the following fields: Comparative politics, political behaviour and attitude formation, public administration, political institutions and public policy, international politics, political theory and political sociology. The goal of the core course in political science is to strengthen the student’s ability to systematically understand, analyse, discuss and independently assess a large amount of research literature and adopt a critical approach to the course literature. Objectives for the core course in political science: The student is able to account for selected theories, methods and issues within the research area in question at the highest academic level. The student is able to identify the most recent Danish and international research results and any needs for further research within the research area in question. In continuation thereof, the student is able to independently formulate an academic hypothesis related to the course theories, methods and issues and to key and current discussions within the research area in question. The student is able to compare the theories, methods and issues presented throughout the course and identify their differences/similarities and strengths/weaknesses. The student is able to apply theories, approaches, methods and data that are relevant for the analysis of the selected issues. The student is able to assess the fruitfulness of the course theories, methods and their scope of application. The student is able to confidently communicate an academic issue and structure an oral academic presentation and engage in a scholarly dialogue about the topic at hand. The specific objectives for this module are: are able to account for and compare selected theories, methods and cases within public administration and to identify differences/similarities and strengths/weaknesses are able to independently formulate a research question related to theories, methods and cases within public administration are able to independently apply theories, approaches, methods and data relevant for the chosen research question are able to independently evaluate the strength of public administration theories, methods and their areas of application",
#     "ECTS 20 Level Master Language of instruction Danish Hours - week - period http://medarbejdere.au.dk/administration/studieadministration/systemer/planlaegning-af-undervisning/timeplaner/ Type of course Ordinary Primary programme Master's Degree Programme in Political Science Department Department of Political Science Faculty Aarhus BSS Maximum number of participants The students need to register for the module. STADS UVA code 431162U091 Copy UVA code",
#     "C Christian Bøtcher Jacobsen H Heidi Houlberg Salomonsen S Søren Serritzlew",
#     "Normally, the course will consist of six lessons per week over the course of 15 weeks. The 90 hours of teaching, which a core course should always consist of, may however be executed differently. The form of instruction may vary, including how the students are expected to contribute in class. However, regardless of the selected form, active participation on the part of students is required. Active participation means: Participation in teaching activities, and the student has an obligation to notify the lecturer/instructor if he/she is unable to attend class. Participation in teaching activities to a reasonable extent, e.g. preparation of presentations, written assignments etc. In the first lesson of the seminar, the lecturer/instructor will present the teaching activities that the seminar will consist of.",
#     "The student agrees with the lecturer the reading which is relevant for the research question of the home assignment. The individual module compendia will normally consists of 2,400 pages",
#     "Preliminary readings listed below. The final curriculum amounts to 2,400 pages. Andersen, L.B., M.L.F. Jakobsen, T. Pallesen & S. Serritzlew (2010). Økonomiske incitamenter i den offentlige sektor, Århus: VIA Systime, pp. 35-49. Andrews, Rhys; Boyne, George A. & Walker, Richard M. (2011). Dimensions of Publicness and Organizational Performance: A Review of the Evidence, Journal of Public Administration Research and Theory, 21(suppl 3): i301-i319. Brehm, John & Scott Gates. 1999. Working, Shirking, and Sabotage. Bureaucratic Responses to a Democratic Public. Ann Aarbor: University of Michigan Press. Carpenter, Daniel P. and George A. Krause. 2012. “Reputation and Public Administration”, Public Administration Review 72: 26-32. Guy Peters, B. 1998. “Managing Horizontal Government: The Politics of Coordination”, Public Administration 76: 295-311. Hvidman, Ulrik & Simon Calmar Andersen (2014). ”Impact of Performance Management in Public and Private Organizations”, Journal of Public Administration research and Theory, 24: 35-58. Kjeldsen, A. M. & C. B. Jacobsen (2013). “Public Service Motivation and Employment Sector: Attraction or Socialization?”. Journal of Public Administration Research and Theory, 23(4): 899-926. Miller, Gary (2005). “The political evolution of principal-agent models”, Annual Review of Political Science, 8: 203-225. Moe, T. M. (1984). The New Economics of Organization, American Journal of Political Science, 28 (4): 739-777. (39 sider) Moynihan, Donald P. (2008). The Dynamics of Performance management. Constructing Information and Reform, Washington D.C.: Georgetown University Press, s. 26-37. Peters, B. Guy & Jon Pierre. 2004. ”Politicization of the Civil Service” pp. 1-11 in Peters, B. Guy & Jon Pierre (eds.). Politicization of the Civil Service in Comparative Perspective. London: Routledge. (12 sider) Roberts, Jennifer & Michael Dietrich (1999). ”Conceptualizing Professionalism: Why Economics needs Sociology”, American Journal of Economics and Sociology, 58, 4: 977-998 Schram, Sanford S., Joe Soss, Richard C. Fording and Linda Houser (2009).” Deciding to Discipline: Race, Choice, and Punishment at the Frontlines of Welfare Reform”, American Sociological Review 74(3), pp. 398-422. Van Ryzin, Gregg G. (2004). ”Expectations, Performance, and Citizen Satisfaction with Urban Services”, Journal of Policy Analysis and Management, 23 (3): 433-448. Weibel, A., K. Rost & M. Osterloh (2010). “Pay for Performance in the Public Sector – Benefits and (Hidden) Costs”, Journal of Public Administration Research and Theory, 20, 2: 387-412.",
#     "To participate in one of the below forms of examination, the student must fulfil the active participation requirements listed above. The lecturer/instructor is obliged to notify the student if he/she does not meet the active participation requirements throughout the semester (warning). If the student is able to meet the requirements after having received this warning, the student will be allowed to participate in the form of examination for the seminar in question. If the student does not meet the requirements, even after the warning has been issued, he/she must complete the course by taking a 6-hour written exam without aids. This form of examination will also (regardless of other provisions in the academic regulations) apply to all re-examinations.",
#     "The synopsis must be prepared in the form of an essay, containing a review of the research literature, reasoned argumentation and a delimitation of a specific topic. The scope of the synopsis is a maximum of 3,000 words. The duration of the oral exam is 40 minutes, including assessment. The examination takes place in two parts. First, a discussion based on the synopsis (15 minutes). Then a discussion based on the course syllabus (15 minutes). One mark is awarded for the overall performance. Re-examinations (both 1. and 2. re-examination) in the political science core courses is the same as for the ordinary exam, i.e. an oral exam with synopsis. Students who due to their study program (i.e. planned exchange visits to countries with a semester structure very dissimilar to ours) are prevented from participation in the oral exam can seek a dispensation to carry through the exam as a written assignment (9.000 words). In those cases, individual supervision dedicated to the synopsis should be converted to supervision dedicated to the written assignment. These rules apply for all students, i.e. also students who are taking the course as a Political Science Double Seminar."
#   ],
#   "coordinator_emails": null,
#   "content": "Read more This seminar provides the participants with in-depth knowledge of the public sector which may be relevant for future jobs and further studies within public administration. We will focus on three main themes: a) coordination and management in the public sector; b) public employees; c) The relationship between the administration and political stakeholders – primarily the citizens. More specifically, we focus on discussing questions such as: Why is coordination and management so difficult in the public sector? What is the relationship between the political leadership and the administration? How can we measure performance in public institutions, and what can we use the knowledge for? How can we manage highly professionalized civil servants and public service providers – and is it even possible? Is there an association between citizen satisfaction and public sector performance? And how can the citizens be motivated to engage in public service co-production initiatives? Discussion of these questions is based on a curriculum focusing on more recent Danish and international scholarly contributions of theoretical as well as empirical content. A main aim of the course is to strengthen the participants written as well as oral performance skills. The oral skills are trained through discussions and group-based casework in class as well as between classes and in the final oral exam. The writing skills are practiced through the requirement of handing in small written assignments during the course where participants should demonstrate ability to develop and describe research designs tackling current empirical challenges in public administration. Hence, the course also serves as preparation for participants’ final thesis writing.",
#   "learning_outcomes": "Read more The seminar provides advanced and in-depth treatment of an area of political science research based on an account and discussion of various positions as well as discussions and possibly data sources and methods derived from conventional and contemporary research literature. These research areas may fall within the following fields: Comparative politics, political behaviour and attitude formation, public administration, political institutions and public policy, international politics, political theory and political sociology. The goal of the core course in political science is to strengthen the student’s ability to systematically understand, analyse, discuss and independently assess a large amount of research literature and adopt a critical approach to the course literature. Objectives for the core course in political science: The student is able to account for selected theories, methods and issues within the research area in question at the highest academic level. The student is able to identify the most recent Danish and international research results and any needs for further research within the research area in question. In continuation thereof, the student is able to independently formulate an academic hypothesis related to the course theories, methods and issues and to key and current discussions within the research area in question. The student is able to compare the theories, methods and issues presented throughout the course and identify their differences/similarities and strengths/weaknesses. The student is able to apply theories, approaches, methods and data that are relevant for the analysis of the selected issues. The student is able to assess the fruitfulness of the course theories, methods and their scope of application. The student is able to confidently communicate an academic issue and structure an oral academic presentation and engage in a scholarly dialogue about the topic at hand. The specific objectives for this module are: are able to account for and compare selected theories, methods and cases within public administration and to identify differences/similarities and strengths/weaknesses are able to independently formulate a research question related to theories, methods and cases within public administration are able to independently apply theories, approaches, methods and data relevant for the chosen research question are able to independently evaluate the strength of public administration theories, methods and their areas of application",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Master",
#   "web_lang": "en"
# }
# ---------------------
#
# === SAMPLE @ 200/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/67612/103M-Advanced-political-behavior",
#   "year": "2016",
#   "course_code": "431162U036",
#   "course_title": "103M Advanced political behavior",
#   "credit": "20",
#   "placement": "Autumn semester 2016",
#   "contracting_department": "Department of Political Science",
#   "coordinators": [
#     "Michael Bang Petersen",
#     "Joshua Robison",
#     "Rune Stubager",
# ...
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Bachelor",
#   "web_lang": "da"
# }
# ---------------------
#
# === SAMPLE @ 440/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/70602/166F17-Majority-Members-Attitudes-toward-Ethnic-Minority-Groups",
#   "year": "2017",
#   "course_code": "431161U012",
#   "course_title": "166F17 Majority Members' Attitudes toward Ethnic Minority Groups",
#   "credit": "20",
#   "placement": "Spring semester 2017",
#   "contracting_department": "Department of Political Science",
#   "coordinators": [
#     "Jens Peter Frølund Thomsen",
#     "This seminar covers majority members’ attitudes toward minority members. The seminar will focus on the international literature and cover prejudice and ethnic relations in a comparative perspective. The focus is on quantitative research in the field of interethnic relations.",
#     "The objective is for the student, after completing the course and participating in lectures and seminars, to be able to: account for the selection of theories, methods and issues from the course compare the theories, methods and issues presented throughout the course and identify their differences/similarities and strengths/weaknesses independently formulate a thesis statement that relates to the theories, methods and issues presented throughout the course apply theories, approaches, methods and data that are relevant for the analysis of the selected issues assess the fruitfulness of the course theories, methods and their scope of application The specific objectives for this module are: To specify a research question To know previous research related to the research question To know and apply key theoretical concepts To advance testable hypotheses and specify relevant measures To perform statistical analyses in a satisfactory manner To present empirical results in a clear and concise way",
#     "ECTS 20 Level Bachelor Language of instruction Danish Hours - week - period http://medarbejdere.au.dk/administration/studieadministration/systemer/planlaegning-af-undervisning/timeplaner/ Type of course Ordinary Primary programme Bachelor's Degree Programme in Political Science Department Department of Political Science Faculty Aarhus BSS Maximum number of participants Each tutorial consists of about 16 students STADS UVA code 431161U012 Copy UVA code",
#     "J Jens Peter Frølund Thomsen",
#     "The module consists of the equivalent of four hours of lectures over 11 weeks. The module also includes an introduction to the written assignment and supervision of the students’ work on the written assignment.",
#     "The students agree their module compendia individually with the module lecturer so as to match the specific research questions at hand. The individual module compendia will normally consists of 1,200 to 1,700 pages.",
#     "The students have to pass the module assessment in the second semester after the students took the initial module.",
#     "The word limit for the written assignment is 10,000 words (about 25 pages), including appendices and notes, but excluding the table of contents, the bibliography and an abstract in English. The abstract forms part of the assessment. Written assignments which exceed word limit will not be accepted."
#   ],
#   "coordinator_emails": null,
#   "content": "Read more This seminar covers majority members’ attitudes toward minority members. The seminar will focus on the international literature and cover prejudice and ethnic relations in a comparative perspective. The focus is on quantitative research in the field of interethnic relations.",
#   "learning_outcomes": "Read more The objective is for the student, after completing the course and participating in lectures and seminars, to be able to: account for the selection of theories, methods and issues from the course compare the theories, methods and issues presented throughout the course and identify their differences/similarities and strengths/weaknesses independently formulate a thesis statement that relates to the theories, methods and issues presented throughout the course apply theories, approaches, methods and data that are relevant for the analysis of the selected issues assess the fruitfulness of the course theories, methods and their scope of application The specific objectives for this module are: To specify a research question To know previous research related to the research question To know and apply key theoretical concepts To advance testable hypotheses and specify relevant measures To perform statistical analyses in a satisfactory manner To present empirical results in a clear and concise way",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Bachelor",
#   "web_lang": "en"
# }
# ---------------------
#
# === SAMPLE @ 450/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/62574/166L-Welfare-State-and-Deliberative-Democracy",
#   "year": null,
#   "course_code": null,
#   "course_title": null,
#   "credit": null,
#   "placement": null,
#   "contracting_department": null,
#   "coordinators": null,
#   "coordinator_emails": null,
#   "content": null,
#   "learning_outcomes": null,
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": null,
#   "level": null,
#   "web_lang": "unknown"
# }
# ---------------------
#
# === SAMPLE @ 460/61705 ===
# {
#   "source_url": "https://kursuskatalog.au.dk/en/course/122192/167F24-Sectarian-Politics-in-a-New-Middle-East",
#   "year": "2024",
#   "course_code": "431231U007",
#   "course_title": "167F24 Sectarian Politics in a New Middle East",
#   "credit": "20",
#   "placement": "Spring semester 2024",
#   "contracting_department": "Department of Political Science",
#   "coordinators": [
#     "Morten Valbjørn, mortenv@ps.au.dk"
#   ],
#   "coordinator_emails": null,
#   "content": "Read more Et af de prominente emner i det seneste tiårs akademiske såvel som bredere debat om et ‘nyt Mellemøsten’ efter de arabiske revolter har handlet om shia-/sunni-skellet og sekterisme i mellemøstlig politik. Nogle observatører har henvist til, hvordan ”a sectarian wave washes over the Middle East” og beskrevet “the new sectarianism” som “a dominant ideological trend” og “a central mobilizing factor”. Det er svært helt at afskrive sekterisme som en faktor, hvis man vender blikket mod den syriske borgerkrig, shia-militsers kamp mod IS i Irak; det seneste årtis rivalisering mellem Iran og Saudi-Arabien; Bahrains al Khalifa-monarkis brug af det ”sekteriske kort” i sin regimeoverlevelsesstrategi; den yemenitiske konflikt, hvor huthierne, al-Qaida, såvel som den saudiskledede ’sunni-alliance’ har gjort brug af sekterisk retorik; i Libanons ”consociational” politiske system; den saudiske undertrykkelse af landets shiitiske mindretal eller valgkampene til det kuwaitiske parlament. Andre observatører har til gengæld kritiseret det “sekteriske masternarrativ” som udtryk for en essentialiserende orientalisme, der “exceptionaliserer” Mellemøsten og fjerner fokus fra de egentlige konfliktlinjer og ”drivers” i regional politik. Her henvises der både til, hvordan forskellige aktører instrumentelt bruger det sekteriske kort i en ganske velkendt kamp om magt og ressourcer, og hvordan der fra det syriske oprørs begyndelse i 2011 til de seneste saudi-iranske tilnærmelser kontinuerligt har været eksempler på tværsekterisk samarbejde og anti-sekteriske aktivisme. Imellem disse poler har der gennem de senere år været en voksende interesse for hverken at reducere mellemøstlig politik til sekterisme eller helt at ignorere den sekteriske faktor. I stedet har der været et ønske om at få en bedre indsigt i, hvor/når/for/dan sekterisme spiller en rolle, hvilke politiske implikationer det har for et ”nyt Mellemøsten”, og hvorvidt/dan studiet af sekterisk politik kan trække på, men også berige teorier og analytiske redskaber fra den bredere forskning om identitetspolitik, etnisk politik, international politik, sociale bevægelser, demokratisering og autokratier. Det er denne trend i studiet af sekterisk politik i et ’nyt Mellemøsten’, som danner omdrejningspunktet for dette BA-opgaveseminar. Mere specifikt er seminaret opdelt i en række overordnede dimensioner. For det første hvad handler shia-/sunni-spørgsmålet i islam overhovedet om? Og giver det mening at bruge en ”sekterisk linse”, som oprindeligt kommer fra en vestlig kristen sammenhæng, og hvordan kan man med kvalitative og kvantitative metoder observere sekterisme uden at se ”for meget” eller ”for lidt”? For det andet hvordan skal sekterisk politik studeres? Er sekterisk politik sammenlignelig med andre former for identitetspolitik, således at man kan bruge almindelige politologiske teorier, eller er det nødvendigt at trække på helt andre faglige traditioner? Hvordan kan forholdet mellem religion og politik begrebsliggøres, og er det analytisk frugtbart at lave sammenligninger mellem det aktuelle shia-/sunni-split i Mellemøsten og fx Nordirlandskonflikten eller den europæiske Trediveårskrig mellem katolikker og protestanter? For det tredje hvor i Mellemøsten spiller sekterisk politik især en rolle i dag, og har betydningen af sekterisk politik forandret sig i forhold til tidligere perioder? For det fjerde hvordan forklarer man, at shia-/sunni-spørgsmålet i de seneste år er kommet til at spille en central rolle i nogle, men ikke andre dele af regionen? Bør man søge tilbage til slaget ved Kerbala i 680, eller skal man snarere se det i lyset af den aktuelle geopolitiske situation, eller er det relevante perspektiv den nære fortid i form af udviklingen i Mellemøsten siden slut-1970erne? Endelig er der for det femte spørgsmålet om, hvilke politiske implikationer de forstærkede shia-/sunni-spændinger har for international politik i Mellemøsten, herunder alliancedannelser og konfliktfor ...
#   "learning_outcomes": "Read more Målet er, at de studerende efter aktivt at have fulgt faget: Har opnået kendskab til forskellige opfattelser af, hvad sekterisme er. Har opnået en grundlæggende forståelse af forskelle og lighedstræk mellem forskellige former for shia- og sunni-islam. Har opnået en detaljeret empirisk viden om forskelle og lighedstræk mht., i hvilket omfang og hvordan sekterisk politik spiller en rolle i forskellige mellemøstlige lande. Har fået et dybdegående kendskab til klassiske og nyere teorier og approaches fra en række forskellige akademiske felter vedr. identitetspolitik, herunder sekterisk politik, såvel som en forståelse for de centrale konfliktlinjer i den akademiske debat herom. Er blevet i stand til at anvende disse teorier og approaches og til at vurdere deres frugtbarhed. Har fået en evne til på nuanceret vis at forstå og forklare fremkomsten og karakteren af en forstærket sekterisk politik i et ’nyt Mellemøsten’. Har fået en evne til på nuanceret vis at forstå og forklare implikationerne af en forstærket sekterisk politik i et ’nyt Mellemøsten’.",
#   "knowledge": null,
#   "skills": null,
#   "competencies": null,
#   "language": "Danish",
#   "level": "Bachelor",
#   "web_lang": "da"
# }
# ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1482564727.py in <cell line: 0>()
#     353         import nest_asyncio  # pip install nest_asyncio
#     354         nest_asyncio.apply()
# --> 355         asyncio.get_event_loop().run_until_complete(main())
#     356     except RuntimeError:
#     357         # No running loop (normal Python script) → safe to use asyncio.run()
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in _run_once(self)
#     131
#     132                 try:
# --> 133                     handle._run()
#     134                 finally:
#     135                     # restore the current task
#
# /usr/lib/python3.12/asyncio/events.py in _run(self)
#      86     def _run(self):
#      87         try:
# ---> 88             self._context.run(self._callback, *self._args)
#      89         except (SystemExit, KeyboardInterrupt):
#      90             raise
#
# /usr/lib/python3.12/asyncio/tasks.py in __step(self, exc)
#     301         _enter_task(self._loop, self)
#     302         try:
# --> 303             self.__step_run_and_handle_result(exc)
#     304         finally:
#     305             _leave_task(self._loop, self)
#
# /usr/lib/python3.12/asyncio/tasks.py in __step_run_and_handle_result(***failed resolving arguments***)
#     312                 # We use the `send` method directly, because coroutines
#     313                 # don't have `__iter__` and `__next__` methods.
# --> 314                 result = coro.send(None)
#     315             else:
#     316                 result = coro.throw(exc)
#
# /usr/local/lib/python3.12/dist-packages/playwright/async_api/_generated.py in abort(self, error_code)
#     666         """
#     667
# --> 668         return mapping.from_maybe_impl(await self._impl_obj.abort(errorCode=error_code))
#     669
#     670     async def fulfill(
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_network.py in abort(self, errorCode)
#     355
#     356     async def abort(self, errorCode: str = None) -> None:
# --> 357         await self._handle_route(
#     358             lambda: self._race_with_page_close(
#     359                 self._channel.send(
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_network.py in _handle_route(self, callback)
#     450         self._check_not_handled()
#     451         try:
# --> 452             await callback()
#     453             self._report_handled(True)
#     454         except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_network.py in _race_with_page_close(self, future)
#     541             fut,
#     542             "__pw_stack__",
# --> 543             getattr(asyncio.current_task(self._loop), "__pw_stack__", inspect.stack(0)),
#     544         )
#     545         target_closed_future = self.request._target_closed_future()
#
# /usr/lib/python3.12/inspect.py in stack(context)
#    1779 def stack(context=1):
#    1780     """Return a list of records for the stack above the caller's frame."""
# -> 1781     return getouterframes(sys._getframe(1), context)
#    1782
#    1783 def trace(context=1):
#
# /usr/lib/python3.12/inspect.py in getouterframes(frame, context)
#    1754     framelist = []
#    1755     while frame:
# -> 1756         traceback_info = getframeinfo(frame, context)
#    1757         frameinfo = (frame,) + traceback_info
#    1758         framelist.append(FrameInfo(*frameinfo, positions=traceback_info.positions))
#
# /usr/lib/python3.12/inspect.py in getframeinfo(frame, context)
#    1712         raise TypeError('{!r} is not a frame or traceback object'.format(frame))
#    1713
# -> 1714     filename = getsourcefile(frame) or getfile(frame)
#    1715     if context > 0:
#    1716         start = lineno - 1 - context//2
#
# /usr/lib/python3.12/inspect.py in getsourcefile(object)
#     968         return filename
#     969     # only return a non-existent filename if the module has a PEP 302 loader
# --> 970     module = getmodule(object, filename)
#     971     if getattr(module, '__loader__', None) is not None:
#     972         return filename
#
# /usr/lib/python3.12/inspect.py in getmodule(object, _filename)
#    1005     # Copy sys.modules in order to cope with changes while iterating
#    1006     for modname, module in sys.modules.copy().items():
# -> 1007         if ismodule(module) and hasattr(module, '__file__'):
#    1008             f = module.__file__
#    1009             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:

# %% [markdown]
# # QA & Viz
